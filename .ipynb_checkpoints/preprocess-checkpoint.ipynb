# %% [markdown]
# # Import Library

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import os
from sklearn import metrics
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # SMOTE For Relax Data Unbalance

# %%
ori_df = pd.read_csv('./dataset/gen/data.csv')

# %%
x_data = ori_df.iloc[:,:-1].to_numpy()
y_data = ori_df.iloc[:,-1].to_numpy()

# %%
smote = SMOTE(random_state=42)
new_x_data,new_y_data = smote.fit_resample(x_data,y_data)
print('SMOTE 적용 전 학습용 피처/레이블 데이터 세트: ', x_data.shape, y_data.shape)
print('SMOTE 적용 후 학습용 피처/레이블 데이터 세트: ', new_x_data.shape, new_y_data.shape)
print('SMOTE 적용 후 레이블 값 분포: \n', pd.Series(new_y_data).value_counts())
# Out:
# SMOTE 적용 전 학습용 피처/레이블 데이터 세트:  (32048, 45) (32048,)
# SMOTE 적용 후 학습용 피처/레이블 데이터 세트:  (45290, 45) (45290,)
# SMOTE 적용 후 레이블 값 분포:
#  0    22645
# 1    22645
# Name: count, dtype: int64

# %%
x_df = pd.DataFrame(new_x_data, columns=ori_df.columns[:-1])
y_df = pd.DataFrame(new_y_data, columns=[ori_df.columns[-1]])
SMOTE_df = pd.concat([x_df,y_df], axis=1)
SMOTE_df
# Out:
#        X_ActualPosition  X_ActualVelocity  X_ActualAcceleration
# 0            202.000000          4.000000              4.000000  \
# 1            202.000000         -6.800000           -346.000000
# 2            200.000000        -13.800000             -2.250000
# 3            198.000000        -14.000000              4.000000
# 4            197.000000        -13.900000            -14.800000
# ...                 ...               ...                   ...
# 45285        164.875376          5.184075            -24.003208
# 45286        159.186290         -3.830530           -971.445575
# 45287        163.708695          4.316441             83.141247
# 45288        173.000000          3.447687            -25.223552
# 45289        154.421181         16.891576            -60.128167
#
#        X_SetPosition  X_SetVelocity  X_SetAcceleration  X_CurrentFeedback
# 0         202.000000       4.000000           4.000000           0.180000  \
# 1         202.000000      -9.600000        -354.000000         -10.900000
# 2         200.000000     -13.900000           3.999905          -8.590000
# 3         198.000000     -13.900000           3.999905          -6.110000
# 4         196.000000     -13.900000           4.000095          -5.700000
# ...              ...            ...                ...                ...
# 45285     164.875376       5.219789           5.000000           2.050301
# 45286     159.186290      -5.779435           5.000000         -18.032339
# 45287     163.708695       4.155709           4.640532           1.204446
# 45288     173.000000       3.500000           3.500000           0.006652
# 45289     154.421181      17.000000           5.000000           7.725596
#
#        X_DCBusVoltage  X_OutputCurrent  X_OutputVoltage  ...  S_SetVelocity
# 0        2.070000e-02       329.000000         2.770000  ...       4.000000  \
# 1        1.860000e-01       328.000000        23.300000  ...       4.000000
# 2        1.400000e-01       328.000000        30.600000  ...       4.000000
# 3        1.300000e-01       327.000000        30.300000  ...       4.000000
# 4        1.140000e-01       328.000000        30.500000  ...       4.000000
# ...               ...              ...              ...  ...            ...
# 45285    4.434864e-02       324.853474         5.462039  ...      58.300000
# 45286    2.918823e-01       324.203428        25.682862  ...      58.300000
# 45287    3.701584e-02       325.286200         1.402896  ...      57.870699
# 45288    2.790000e-19       328.000000         0.000000  ...      30.150000
# 45289    1.099266e-01       324.000000        21.791576  ...      58.300000
#
#        S_SetAcceleration  S_CurrentFeedback  S_DCBusVoltage  S_OutputCurrent
# 0               4.000000           0.524000    2.740000e-19       329.000000  \
# 1               4.000000          -0.288000    2.740000e-19       328.000000
# 2               4.000000           0.524000    2.740000e-19       328.000000
# 3               4.000000          -0.180000    2.740000e-19       328.000000
# 4               4.000000           0.226000    2.740000e-19       328.000000
# ...                  ...                ...             ...              ...
# 45285           5.000000          23.687915    9.722357e-01       320.706948
# 45286           5.000000          23.177721    9.261647e-01       320.186290
# 45287           4.570699          23.644121    1.013653e+00       319.000000
# 45288           3.500000          -2.535778    0.000000e+00       331.000000
# 45289           5.000000          25.512270    1.003153e+00       321.000000
#
#        S_OutputVoltage  S_OutputPower  S_SystemInertia  M_CURRENT_FEEDRATE
# 0             0.000000   6.960000e-07        16.000000           50.000000  \
# 1             0.000000  -5.270000e-07        16.000000           50.000000
# 2             0.000000   9.100000e-07        16.000000           50.000000
# 3             0.000000   1.070000e-06        16.000000           50.000000
# 4             0.000000   1.960000e-06        16.000000           50.000000
# ...                ...            ...              ...                 ...
# 45285       117.853474   1.870076e-01        17.000000            8.051361
# 45286       118.000000   1.773212e-01        17.000000           10.779435
# 45287       115.000000   1.955588e-01        16.570699           28.586012
# 45288         0.000000  -6.136825e-06        15.500000           50.000000
# 45289       119.084236   1.925463e-01        17.000000           12.000000
#
#        error
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 45285      1
# 45286      1
# 45287      1
# 45288      1
# 45289      1
#
# [45290 rows x 46 columns]

# %%
SMOTE_df.to_csv('./dataset/gen/SMOTE_df.csv',index=False)

# %% [markdown]
# # Preprocess For PCA

# %%
ori_df = pd.read_csv('./dataset/gen/SMOTE_df.csv')

# %%
pd.set_option('display.max_columns', 50)

# %%
ori_df
# Out:
#        X_ActualPosition  X_ActualVelocity  X_ActualAcceleration
# 0            202.000000          4.000000              4.000000  \
# 1            202.000000         -6.800000           -346.000000
# 2            200.000000        -13.800000             -2.250000
# 3            198.000000        -14.000000              4.000000
# 4            197.000000        -13.900000            -14.800000
# ...                 ...               ...                   ...
# 45285        164.875376          5.184075            -24.003208
# 45286        159.186290         -3.830530           -971.445575
# 45287        163.708695          4.316441             83.141247
# 45288        173.000000          3.447687            -25.223552
# 45289        154.421181         16.891576            -60.128167
#
#        X_SetPosition  X_SetVelocity  X_SetAcceleration  X_CurrentFeedback
# 0         202.000000       4.000000           4.000000           0.180000  \
# 1         202.000000      -9.600000        -354.000000         -10.900000
# 2         200.000000     -13.900000           3.999905          -8.590000
# 3         198.000000     -13.900000           3.999905          -6.110000
# 4         196.000000     -13.900000           4.000095          -5.700000
# ...              ...            ...                ...                ...
# 45285     164.875376       5.219789           5.000000           2.050301
# 45286     159.186290      -5.779435           5.000000         -18.032339
# 45287     163.708695       4.155709           4.640532           1.204446
# 45288     173.000000       3.500000           3.500000           0.006652
# 45289     154.421181      17.000000           5.000000           7.725596
#
#        X_DCBusVoltage  X_OutputCurrent  X_OutputVoltage  X_OutputPower
# 0        2.070000e-02       329.000000         2.770000      -0.000001  \
# 1        1.860000e-01       328.000000        23.300000       0.004480
# 2        1.400000e-01       328.000000        30.600000       0.005330
# 3        1.300000e-01       327.000000        30.300000       0.004890
# 4        1.140000e-01       328.000000        30.500000       0.004250
# ...               ...              ...              ...            ...
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 45285      1
# 45286      1
# 45287      1
# 45288      1
# 45289      1
#
# [45290 rows x 46 columns]

# %%
y = ori_df['error']
x = ori_df.drop(['error'],axis=1)
col = x.columns
# df = df.values

x = StandardScaler().fit_transform(x)

df = pd.DataFrame(x,columns=col)
df
# Out:
#        X_ActualPosition  X_ActualVelocity  X_ActualAcceleration
# 0              1.848732          0.007763             -0.009326  \
# 1              1.848732         -1.754037             -3.602575
# 2              1.746158         -2.895944             -0.073491
# 3              1.643584         -2.928570             -0.009326
# 4              1.592298         -2.912257             -0.202335
# ...                 ...               ...                   ...
# 45285         -0.055272          0.200920             -0.296819
# 45286         -0.347048         -1.269628            -10.023665
# 45287         -0.115108          0.059384              0.803172
# 45288          0.361414         -0.082336             -0.309347
# 45289         -0.591435          2.110760             -0.667693
#
#        X_SetPosition  X_SetVelocity  X_SetAcceleration  X_CurrentFeedback
# 0           1.848686       0.007224          -0.002820           0.169484  \
# 1           1.848686      -2.209327          -4.517477          -2.519335
# 2           1.746121      -2.910148          -0.002821          -1.958760
# 3           1.643557      -2.910148          -0.002821          -1.356931
# 4           1.540992      -2.910148          -0.002819          -1.257435
# ...              ...            ...                ...                ...
# 45285      -0.055151       0.206027           0.009791           0.623356
# 45286      -0.346900      -1.586645           0.009791          -4.250162
# 45287      -0.114981       0.032602           0.005258           0.418089
# 45288       0.361499      -0.074267          -0.009125           0.127417
# 45289      -0.591266       2.125986           0.009791           2.000597
#
#        X_DCBusVoltage  X_OutputCurrent  X_OutputVoltage  X_OutputPower
# 0           -0.960476         1.399422        -0.573282      -0.408629  \
# 1            2.915621         0.782766         1.543063       1.825212
# 2            1.836973         0.782766         2.295588       2.248909
# 3            1.602485         0.166110         2.264662       2.029584
# 4            1.227303         0.782766         2.285279       1.710565
# ...               ...              ...              ...            ...
# 45285       -0.405942        -1.157557        -0.295772      -0.414227
# 45286        5.398440        -1.558412         1.788702       2.595615
# 45287       -0.577888        -0.890714        -0.714210      -0.404726
# 45288       -1.445867         0.782766        -0.858829      -0.407921
# 45289        1.131786        -1.683856         1.387567       0.919369
#
#        Y_ActualPosition  Y_ActualVelocity  Y_ActualAcceleration
# 0              1.848194          0.020022             -0.084565  \
# 1              1.848194         -3.043018             -8.330221
# 2              1.712426         -5.010180             -0.015274
# 3              1.610599         -5.025669             -0.708186
# 4              1.508773         -4.932732              1.514677
# ...                 ...               ...                   ...
# 45285         -0.042617         -0.380179              2.340976
# 45286         -0.191823          0.188764              0.366785
# 45287         -0.607480         -1.722538             -0.780513
# 45288          0.451858          0.186964              0.035654
# 45289         -0.952030          0.159753             -0.685426
#
#        Y_SetPosition  Y_SetVelocity  Y_SetAcceleration  Y_CurrentFeedback
# 0           1.848381       0.021223          -0.028093           0.129834  \
# 1           1.814437      -3.790024          -7.264296          -3.301329
# 2           1.712607      -4.982976          -0.028094          -1.770435
# 3           1.610777      -4.982976          -0.028094          -1.848007
# 4           1.508948      -4.982976          -0.028091          -3.141623
# ...              ...            ...                ...                ...
# 45285      -0.042498      -0.390203          -0.016908          -1.228807
# 45285          0.804164             -2.198065       0.109376       0.816633
# 45286          0.808367             -0.053775       0.959689       0.816633
# 45287          0.793426              0.047926       0.052825       0.798454
# 45288         -0.395046             -0.213531      -0.036790      -0.375428
# 45289          0.808218              0.956936       1.481531       0.816633
#
#        S_SetAcceleration  S_CurrentFeedback  S_DCBusVoltage  S_OutputCurrent
# 0              -0.110129          -1.112886       -1.194479         1.239736  \
# 1              -0.110129          -1.185759       -1.194479         1.023764
# 2              -0.110129          -1.112886       -1.194479         1.023764
# 3              -0.110129          -1.176067       -1.194479         1.023764
# 4              -0.110129          -1.139630       -1.194479         1.023764
# ...                  ...                ...             ...              ...
# 45285           0.053742           0.965945        0.844856        -0.551333
# 45286           0.053742           0.920158        0.748219        -0.663781
# 45287          -0.016608           0.962015        0.931731        -0.919986
# 45288          -0.192064          -1.387484       -1.194479         1.671681
# 45289           0.053742           1.129671        0.909707        -0.488042
#
#        S_OutputVoltage  S_OutputPower  S_SystemInertia  M_CURRENT_FEEDRATE
# 0            -1.248587      -1.220195        -0.273470            1.380607
# 1            -1.248587      -1.220209        -0.273470            1.380607
# 2            -1.248587      -1.220193        -0.273470            1.380607
# 3            -1.248587      -1.220191        -0.273470            1.380607
# 4            -1.248587      -1.220181        -0.273470            1.380607
# ...                ...            ...              ...                 ...
# 45285         0.803248       0.892726         0.889886           -0.681485
# 45286         0.805799       0.783283         0.889886           -0.547380
# 45287         0.753569       0.989343         0.390456            0.327948
# 45288        -1.248587      -1.220273        -0.855149            1.380607
# 45289         0.824676       0.955306         0.889886           -0.487380
#
# [45290 rows x 45 columns]

# %%
features =x.T  # X 데이터는 150 × 4 이라면,
               # feature 는 4 × 150 이다.

cov_mat = np.cov(features)
cov_mat
# Out:
# array([[ 1.00002208, -0.0293692 , -0.02374486, ..., -0.6298912 ,
#         -0.09491919,  0.40805957],
#        [-0.0293692 ,  1.00002208,  0.04320129, ...,  0.03695697,
#          0.15769234, -0.01668134],
#        [-0.02374486,  0.04320129,  1.00002208, ...,  0.00356348,
#          0.02110946,  0.00562858],
#        ...,
#        [-0.6298912 ,  0.03695697,  0.00356348, ...,  1.00002208,
#          0.11182204, -0.7563362 ],
#        [-0.09491919,  0.15769234,  0.02110946, ...,  0.11182204,
#          1.00002208, -0.07417508],
#        [ 0.40805957, -0.01668134,  0.00562858, ..., -0.7563362 ,
#         -0.07417508,  1.00002208]])

# %%
values, vectors = np.linalg.eig(cov_mat)

print('\nEigenvalues \n%s '% values[:])
print('\nEigenvectros \n%s'  %  vectors[:])
# Out:
# Eigenvalues
# [1.30652500e+01 4.44561709e+00 3.20637427e+00 2.06359642e+00
#  1.92330979e+00 1.88856847e+00 1.80711014e+00 1.53954936e+00
#  1.42879011e+00 1.34468415e+00 1.27586741e+00 1.17102050e+00
#  9.78387590e-01 8.48304071e-01 6.83101099e-01 5.52167451e-01
#  5.15024782e-01 3.90526202e-01 3.32544690e-01 2.84167958e-01
#  2.23645588e-01 1.76700628e-01 1.62590314e-01 1.54105391e-01
#  1.33408583e-01 1.15220530e-01 1.00978262e-01 5.82296791e-02
#  3.58939390e-02 3.44359576e-02 2.86460611e-02 1.71068282e-02
#  8.92909872e-03 5.77656191e-03 5.91632390e-04 5.26668908e-04
#  8.79565569e-05 6.63761722e-05 2.80560535e-06 4.95731513e-07
#  4.37145465e-07 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00]
#
# Eigenvectros
# [[-0.22429669  0.04067479  0.08146574 ...  0.          0.
#    0.        ]
#  [ 0.0153477  -0.17761228  0.42234093 ...  0.          0.
#    0.        ]
#  [ 0.0053905   0.00145068  0.09954188 ...  0.          0.
#    0.        ]
#  ...
#  [ 0.25734289 -0.04289254 -0.02895584 ...  0.          0.
#    0.        ]
#  [ 0.03478772 -0.077543    0.06442835 ...  0.          0.
#    0.        ]
#  [-0.19326707  0.07459373  0.07055551 ...  0.          0.
#    0.        ]]

# %%
explained_variances = []
for i in range(len(values)):
    explained_variances.append(values[i] / np.sum(values))
explained_variances
# Out:
# [0.31865759694629037,
#  0.10842729088797527,
#  0.07820252385716067,
#  0.05033050866273638,
#  0.04690895905965834,
#  0.04606162844037692,
#  0.044074883913092326,
#  0.03754915523241557,
#  0.034847769933084964,
#  0.0327964501198973,
#  0.031118030217420774,
#  0.028560845035877313,
#  0.023862585061298208,
#  0.020689886360895367,
#  0.01666063454663874,
#  0.013467201432287199,
#  0.012561302691123898,
#  0.009524819001383406,
#  0.00811066701623367,
#  0.006930772772766359,
#  0.005454650008797618,
#  0.00430967625785677,
#  0.003965529854455467,
#  0.0037585850871998086,
#  0.003253796022536539,
#  0.0028101947686256764,
#  0.0024628300665547995,
#  0.0014202047171592831,
#  0.0008754425978179137,
#  0.0008398828599759307,
#  0.0006986689911257292,
#  0.00041723049982428487,
#  0.00021777808705203628,
#  0.00014088864295843314,
#  1.4429739680745875e-05,
#  1.2845299493341597e-05,
#  2.145234507781338e-06,
#  1.6188952822768043e-06,
#  6.842788790779202e-08,
#  1.20907455514877e-08,
#  1.0661849101996809e-08,
#  0.0,
#  0.0,
#  0.0,
#  0.0]

# %%
a = 0
lst = []

for idx, var in enumerate(explained_variances):
    a += var
    print(idx, a)
    lst.append(a)
# Out:
# 0 0.31865759694629037
# 1 0.4270848878342656
# 2 0.5052874116914263
# 3 0.5556179203541627
# 4 0.602526879413821
# 5 0.648588507854198
# 6 0.6926633917672903
# 7 0.7302125469997058
# 8 0.7650603169327908
# 9 0.797856767052688
# 10 0.8289747972701088
# 11 0.8575356423059861
# 12 0.8813982273672843
# 13 0.9020881137281798
# 14 0.9187487482748184
# 15 0.9322159497071056
# 16 0.9447772523982295
# 17 0.9543020713996129
# 18 0.9624127384158465
# 19 0.9693435111886128
# 20 0.9747981611974105
# 21 0.9791078374552672
# 22 0.9830733673097226
# 23 0.9868319523969225
# 24 0.990085748419459
# 25 0.9928959431880846
# 26 0.9953587732546394
# 27 0.9967789779717987
# 28 0.9976544205696166
# 29 0.9984943034295926
# 30 0.9991929724207183
# 31 0.9996102029205426
# 32 0.9998279810075946
# 33 0.9999688696505531
# 34 0.9999832993902339
# 35 0.9999961446897272
# 36 0.999998289924235
# 37 0.9999999088195173
# 38 0.9999999772474052
# 39 0.9999999893381507
# 40 0.9999999999999998
# 41 0.9999999999999998
# 42 0.9999999999999998
# 43 0.9999999999999998
# 44 0.9999999999999998

# %%
plt.plot(explained_variances)
plt.show()

# %%
compo = 11
pca = PCA(n_components=compo) # 주성분을 몇개로 할지 결정
printcipalComponents = pca.fit_transform(x)
pdf = pd.DataFrame(data=printcipalComponents,
                   columns = [f'pca{num+1}' for num in range(compo)])
pdf['error'] = y
pdf
# Out:
#            pca1       pca2      pca3      pca4      pca5       pca6
# 0     -6.141346  -0.210727  0.552068 -0.231081 -0.356076  -0.729428  \
# 1     -3.868874  11.713991  0.125772 -2.223700  5.579156 -13.580853
# 2     -4.287864  12.596600 -1.230342 -0.310849 -1.064841  -0.463320
# 3     -3.887103  12.724230 -0.968729 -0.603924 -0.720260  -0.836921
# 4     -3.881390  13.217775 -0.959855 -0.630892 -1.009089  -0.242315
# ...         ...        ...       ...       ...       ...        ...
# 45285  2.636730   0.519015  0.265643 -0.900571 -0.149818  -0.423326
# 45286  4.090798   1.917094 -1.568426  4.231461 -2.654866  -2.894067
# 45287  2.610888   1.671040 -0.275974 -1.216111  0.305665   0.068854
# 45288 -4.201018  -0.876240 -0.727445 -0.087574 -0.102708   0.907807
# 45289  3.987817  -0.897945  2.761666 -2.374881 -0.850301   0.001185
#
#             pca7      pca8      pca9     pca10     pca11  error
# 0      -0.655811 -0.195823  0.063237 -0.019793  0.011398      0
# 1      10.208132 -2.302201 -6.766256  4.925644 -1.573978      0
# 2      -1.007749 -0.198258  0.110116 -0.175923  0.307253      0
# 3      -0.755046 -0.415317 -0.002986 -0.108238  0.115317      0
# 4      -0.845005  0.932561  0.343599 -0.275745  0.135319      0
# ...          ...       ...       ...       ...       ...    ...
# 45285  -1.102026  1.645235  0.459114 -0.025133 -1.345897      1
# 45286  -0.740870  1.160423 -5.761159 -0.504553 -0.851290      1
# 45287  -0.275316 -0.023066 -0.075425  0.191033 -0.492059      1
# 45288   1.224124  0.497701  0.204106  0.256150 -0.076577      1
# 45289   0.434856  0.387146 -1.321604 -0.841110  0.964977      1
#
# [45290 rows x 12 columns]

# %%
pdf.to_csv('./dataset/gen/pca_df.csv',index=False)

# %%
pca.explained_variance_ratio_
# Out:
# array([0.3186576 , 0.10842729, 0.07820252, 0.05033051, 0.04690896,
#        0.04606163, 0.04407488, 0.03754915, 0.03484777, 0.03279645,
#        0.03111803])

# %%
sum(pca.explained_variance_ratio_)
# Out:
# 0.8289747950764703

# %%
x_data = pdf.iloc[:,:len(pdf.columns)-1].to_numpy()
y_data = pdf.iloc[:,-1].to_numpy()

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.2, random_state=0)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.25, random_state=0)
print(x_train.shape, x_val.shape, x_test.shape)
# Out:
# (27174, 11) (9058, 11) (9058, 11)

# %%
x_train = x_train.reshape(x_train.shape[0],-1,1)
x_val = x_val.reshape(x_val.shape[0],-1,1)
x_test = x_test.reshape(x_test.shape[0],-1,1)

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 9771784016343956426
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 3643801600
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 713230648190606602
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
dropout_prob = (0.3, 0.8)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense,Dropout,Input, Activation, BatchNormalization

model = Sequential() # Sequeatial Model
# model.add(Dense(32, activation="relu",input_shape=(10,)))
model.add(Dense(128, activation="relu",input_shape=(11,)))
model.add(Dense(128, activation="relu"))
model.add(Dropout(dropout_prob[0]))
model.add(Dense(64, activation="relu"))
model.add(Dense(64, activation="relu"))
model.add(Dropout(dropout_prob[0]))
model.add(Dense(16, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               1536
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 16)                1040
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 31,521
# Trainable params: 31,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=6, mode='min'),
             tf.keras.callbacks.ModelCheckpoint('./best.h5', monitor='val_loss',save_best_only=True, mode='min')
            ]

model.fit(x_train, y_train, epochs=100, validation_data = (x_val, y_val),
          batch_size=64, verbose=1, callbacks=callbacks)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 7
#       1 from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
#       3 callbacks = [tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=6, mode='min'),
#       4              tf.keras.callbacks.ModelCheckpoint('./best.h5', monitor='val_loss',save_best_only=True, mode='min')
#       5             ]
# ----> 7 model.fit(x_train, y_train_over, epochs=100, validation_data = (x_val, y_val),
#       8           batch_size=64, verbose=1, callbacks=callbacks)
#
# NameError: name 'y_train_over' is not defined

# %%
model.evaluate(x_test,y_test)

# %%
y_pred = model.predict(x_test)

print(y_pred)
# Out:
# 284/284 [==============================] - 1s 3ms/step
# [[2.3329176e-06]
#  [1.0751045e-08]
#  [7.8624851e-01]
#  ...
#  [9.9137324e-01]
#  [3.0486109e-07]
#  [6.3668676e-02]]

# %%
y_pred.shape
# Out:
# (9058, 1)

# %%
y_pred = y_pred.reshape(-1)

for y in range(len(y_pred)):
    if y_pred[y] >= 0.5:
        y_pred[y] = 1
    else:
        y_pred[y] = 0
        
y_pred = y_pred.reshape(-1,1)
y_pred
# Out:
# array([[0.],
#        [0.],
#        [1.],
#        ...,
#        [1.],
#        [0.],
#        [0.]], dtype=float32)

# %%
confusion_matrix = metrics.confusion_matrix(y_test, y_pred)
print(confusion_matrix)
# Out:
# [[4166  363]
#  [ 124 4405]]

# %%
accuracy = metrics.accuracy_score(y_test, y_pred)
print("정확도:", accuracy)

precision = metrics.precision_score(y_test, y_pred)
print("정밀도:", precision)

recall = metrics.recall_score(y_test, y_pred)
print("재현율:", recall)

f1 = metrics.f1_score(y_test, y_pred)
print("f1 점수:", f1)
# Out:
# 정확도: 0.9462353720468094
# 정밀도: 0.9238674496644296
# 재현율: 0.9726208876131597
# f1 점수: 0.9476175110250619

# %%
fig = plt.figure(figsize = (8, 8))
ax = fig.add_subplot(111, projection='3d')
# ax = fig.add_subplot(1, 1, 1)
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_zlabel('Principal Component 3', fontsize = 15)
ax.set_title('3 component PCA', fontsize=20)

targets = pdf['error'].unique()
for target in targets:
    indicesToKeep = (pdf['error'] == target)
    ax.scatter(pdf.loc[indicesToKeep, 'pca1']
               , pdf.loc[indicesToKeep, 'pca2']
               , pdf.loc[indicesToKeep, 'pca3']
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
ori_df = pd.read_csv('./dataset/gen/melting_tank.csv')
ori_df['TAG']=ori_df['TAG'].replace('OK',1)
ori_df['TAG']=ori_df['TAG'].replace('NG',0)
ori_df = ori_df.drop(['STD_DT','NUM'], axis=1)

# %%
ori_df

# %%
y = ori_df['TAG']
x = ori_df.drop(['TAG'],axis=1)
col = x.columns
# df = df.values

x = StandardScaler().fit_transform(x)

df = pd.DataFrame(x,columns=col)
df
