# %% [markdown]
# # Set Environment

# %%
from tensorflow.python.client import device_lib
import os
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6369894489185313716
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 3643801600
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 10107465118612600096
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6"
#  xla_global_id: 416903419]

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %% [markdown]
# # HomeMade PCA 불러오기

# %%
from tool import handmade_pca
# Out:
# Handmade PCA가 초기화 되었습니다.
# pandas 라이브러리를 불러온 후, 'data = pandas.read_csv(데이터 경로)' 코드를 통해 데이터를 준비해주세요.
# 데이터를 준비했다면, 'pca = handmade_pca(data)' 코드를 통해 분석을 시작해주세요.

# %% [markdown]
# # 필요 라이브러리 추가로 불러오기

# %%
import pandas as pd # as를 통해 패키지명 축약 가능

# %% [markdown]
# # HandMade PCA 이용하여 분석 진행

# %% [markdown]
# ## CNC 데이터

# %% [markdown]
# ### Pandas를 통해 데이터 준비하기

# %%
exp_path = './dataset/raw/exp/'
label_data = pd.read_csv('./dataset/raw/train.csv')

# %% [markdown]
# ### 전처리 및 시각화 진행

# %%
cnc_pca = handmade_pca(exp_path, label_data)
# Out:
# '.set_data()'를 통해 변수를 지정하고 분석을 위한 데이터를 생성해주세요.

# %%
cnc_pca.set_data()
# Out:
# 변수:
# 1 X_ActualPosition
# 2 X_ActualVelocity
# 3 X_ActualAcceleration
# 4 X_SetPosition
# 5 X_SetVelocity
# 6 X_SetAcceleration
# 7 X_CurrentFeedback
# 8 X_DCBusVoltage
# 9 X_OutputCurrent
# 10 X_OutputVoltage
# 11 X_OutputPower
# 12 Y_ActualPosition
# 13 Y_ActualVelocity
# 14 Y_ActualAcceleration
# 15 Y_SetPosition
# 16 Y_SetVelocity
# 17 Y_SetAcceleration
# 18 Y_CurrentFeedback
# 19 Y_DCBusVoltage
# 20 Y_OutputCurrent
# 21 Y_OutputVoltage
# 22 Y_OutputPower
# 23 Z_ActualPosition
# 24 Z_ActualVelocity
# 25 Z_ActualAcceleration
# 26 Z_SetPosition
# 27 Z_SetVelocity
# 28 Z_SetAcceleration
# 29 Z_CurrentFeedback
# 30 Z_DCBusVoltage
# 31 Z_OutputCurrent
# 32 Z_OutputVoltage
# 33 S_ActualPosition
# 34 S_ActualVelocity
# 35 S_ActualAcceleration
# 36 S_SetPosition
# 37 S_SetVelocity
# 38 S_SetAcceleration
# 39 S_CurrentFeedback
# 40 S_DCBusVoltage
# 41 S_OutputCurrent
# 42 S_OutputVoltage
# 43 S_OutputPower
# 44 S_SystemInertia
# 45 M_CURRENT_PROGRAM_NUMBER
# 46 M_sequence_number
# ...

# %%
cnc_pca.to_number()
# Out:
# 데이터 불균형이 존재합니다. '.smote()'를 통한 데이터 불균형 해소를 추천합니다.'
# SMOTE는 최근접 이웃(k-NN) 알고리즘을 기반으로 하여 데이터를 새로 생성해 종속변수 데이터가 같은 비율을 갖게 하는 알고리즘 입니다.

# %%
cnc_pca.smote()
# Out:
# 기존 데이터 형태:  (32048, 48) (32048,)
# SMOTE 적용 후 데이터 형태:  (45290, 48) (45290,)
# SMOTE 적용 후 종속변수 데이터 분포:
#  0    22645
# 1    22645
# Name: count, dtype: int64
#
# 분석을 위한 데이터 생성이 완료되었습니다. '.train_split()'을 통해 데이터 분할을 진행하세요.
#
# 독립변수의 수가 너무 많다면 '.pca()'를 통한 차원 축소를 추천합니다.

# %%
cnc_pca.pca()
# Out:
#                 PC1       PC2       PC3       PC4       PC5       PC6
# 고유값       14.961557  5.309457  3.665949  2.363318  2.100051  2.003255  \
# 기여율(설명력)   0.303941  0.107861  0.074473  0.048010  0.042662  0.040696
# 누적 기여율     0.303941  0.411802  0.486275  0.534285  0.576947  0.617643
#
#                PC7       PC8       PC9      PC10      PC11      PC12
# 고유값       1.891533  1.751637  1.663122  1.616662  1.426648  1.353003  \
# 기여율(설명력)  0.038426  0.035584  0.033786  0.032842  0.028982  0.027486
# 누적 기여율    0.656069  0.691653  0.725439  0.758281  0.787263  0.814749
#
#               PC13      PC14      PC15      PC16      PC17      PC18
# 고유값       1.220702  1.074355  0.958017  0.844447  0.760245  0.685941  \
# 기여율(설명력)  0.024798  0.021825  0.019462  0.017155  0.015444  0.013935
# 누적 기여율    0.839548  0.861373  0.880835  0.897990  0.913434  0.927369
#
#               PC19      PC20      PC21      PC22      PC23      PC24
# ...

# %%
cnc_pca.pca_visualize(dimension='3d')

# %%
cnc_pca.train_split()
# Out:
# 원하는 훈련용/시험용 데이터 비율을 입력해주세요. (추천: 0.8 0.2)
# 숫자 0을 입력하면 추천 개수로 데이터 분할을 진행합니다.
#
# 원하는 데이터 비율: 0
# 학습용 데이터 수: 36232
# 시험용 데이터 수: 9058
# 데이터 분할을 완료했습니다. '.train()'를 통해 학습을 시작해주세요.

# %%
cnc_pca.train() # 로지스틱 회귀
# Out:
# 1 로지스틱 회귀
# 2 서포트벡터머신
# 3 랜덤포레스트
# 4 XGBOOST
# 5 DNN
# 학습을 진행하기 위해 모델 리스트 중 원하는 모델의 번호를 입력해주세요.1
#
# 로지스틱 회귀 모델을 선택했습니다.
# 학습 중...
# 학습이 종료되었습니다.
# 다른 모델을 추가로 학습하려면 다시 '.train()'를 실행하세요.
# 학습한 모델들의 평가지표를 확인하려면 '.evaluate()'를 실행하세요.

# %%
cnc_pca.train() # 서포트벡터머신
# Out:
# 1 로지스틱 회귀
# 2 서포트벡터머신
# 3 랜덤포레스트
# 4 XGBOOST
# 5 DNN
# 학습을 진행하기 위해 모델 리스트 중 원하는 모델의 번호를 입력해주세요.2
#
# 서포트벡터머신 모델을 선택했습니다.
# 학습 중...
# 학습이 종료되었습니다.
# 다른 모델을 추가로 학습하려면 다시 '.train()'를 실행하세요.
# 학습한 모델들의 평가지표를 확인하려면 '.evaluate()'를 실행하세요.

# %%
cnc_pca.train() # 랜덤 포레스트
# Out:
# 1 로지스틱 회귀
# 2 서포트벡터머신
# 3 랜덤포레스트
# 4 XGBOOST
# 5 DNN
# 학습을 진행하기 위해 모델 리스트 중 원하는 모델의 번호를 입력해주세요.3
#
# 랜덤 포레스트 모델을 선택했습니다.
# 학습 중...
# 학습이 종료되었습니다.
# 다른 모델을 추가로 학습하려면 다시 '.train()'를 실행하세요.
# 학습한 모델들의 평가지표를 확인하려면 '.evaluate()'를 실행하세요.

# %%
cnc_pca.train() # XGBOOST
# Out:
# 1 로지스틱 회귀
# 2 서포트벡터머신
# 3 랜덤포레스트
# 4 XGBOOST
# 5 DNN
# 학습을 진행하기 위해 모델 리스트 중 원하는 모델의 번호를 입력해주세요.4
#
# XGBOOST 모델을 선택했습니다. 학습을 진행하기 위해 학습용 데이터에서 검증용 데이터를 추출 해야합니다.
# 원하는 검증용 데이터 비율을 전체 데이터셋에 대한 비율로 입력해주세요 (추천: 0.2)
# 숫자 0을 입력하면 추천 개수로 데이터 분할을 진행합니다.
#
# 원하는 데이터 비율: 0
# [0]	train-error:0.06385	eval-error:0.08644
# [1]	train-error:0.05652	eval-error:0.07827
# [2]	train-error:0.04777	eval-error:0.07043
# [3]	train-error:0.04795	eval-error:0.06988
# [4]	train-error:0.04512	eval-error:0.06602
# [5]	train-error:0.04456	eval-error:0.06745
# [6]	train-error:0.04350	eval-error:0.06569
# [7]	train-error:0.04328	eval-error:0.06447
# [8]	train-error:0.04192	eval-error:0.06447
# [9]	train-error:0.04173	eval-error:0.06337
# [10]	train-error:0.04092	eval-error:0.06381
# [11]	train-error:0.03985	eval-error:0.06381
# [12]	train-error:0.03835	eval-error:0.06348
# [13]	train-error:0.03728	eval-error:0.06315
# [14]	train-error:0.03588	eval-error:0.06282
# [15]	train-error:0.03463	eval-error:0.06238
# ...

# %%
cnc_pca.train() # DNN
# Out:
# 1 로지스틱 회귀
# 2 서포트벡터머신
# 3 랜덤포레스트
# 4 XGBOOST
# 5 DNN
# 학습을 진행하기 위해 모델 리스트 중 원하는 모델의 번호를 입력해주세요.5
#
# DNN 모델을 선택했습니다. 학습을 진행하기 위해 학습용 데이터에서 검증용 데이터를 추출 해야합니다.
# 원하는 검증용 데이터 비율을 전체 데이터셋에 대한 비율로 입력해주세요 (추천: 0.2)
# 숫자 0을 입력하면 추천 개수로 데이터 분할을 진행합니다.
#
# 원하는 데이터 비율: 0
# Epoch 1/300
# 213/213 [==============================] - 5s 13ms/step - loss: 0.4596 - acc: 0.8088 - val_loss: 0.3343 - val_acc: 0.8598
# Epoch 2/300
# 213/213 [==============================] - 2s 10ms/step - loss: 0.3286 - acc: 0.8594 - val_loss: 0.2663 - val_acc: 0.8917
# Epoch 3/300
# 213/213 [==============================] - 2s 11ms/step - loss: 0.2782 - acc: 0.8836 - val_loss: 0.2260 - val_acc: 0.9067
# Epoch 4/300
# 213/213 [==============================] - 2s 11ms/step - loss: 0.2543 - acc: 0.8955 - val_loss: 0.2011 - val_acc: 0.9175
# Epoch 5/300
# 213/213 [==============================] - 2s 11ms/step - loss: 0.2322 - acc: 0.9058 - val_loss: 0.1907 - val_acc: 0.9212
# Epoch 6/300
# ...

# %%
cnc_pca.evaluate()
# Out:
# 평가가 진행 중 입니다.
# 284/284 [==============================] - 1s 3ms/step
# 모델 평가가 완료되었습니다. '.predict()'를 통해 예측을 진행하세요.
#               정확도       정밀도       재현율     F1 점수
# 랜덤 포레스트  0.936410  0.917410  0.958518  0.937514
# DNN      0.952087  0.915884  0.995120  0.953859
# XGBOOST  0.955619  0.943030  0.969388  0.956027
# 로지스틱 회귀  0.771252  0.781553  0.750000  0.765452
# 서포트벡터머신  0.962575  0.946838  0.979814  0.963044

# %% [markdown]
# # 업데이트 예정..
